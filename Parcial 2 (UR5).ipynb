# %%
from roboticstoolbox import DHRobot,RevoluteDH,PrismaticDH
import roboticstoolbox as rtb
import numpy as np
from math import pi
import matplotlib.pyplot as plt
from spatialmath import *
from roboticstoolbox.backends.swift import Swift

# %%
robot = rtb.models.UR5()

# %%
print(robot)
print(robot.links)
print(robot.qr)
# Out:
# ERobot: UR5 (by Universal Robotics), 6 joints (RRRRRR), 2 branches, dynamics, geometry, collision
# ┌───┬────────────────┬───────┬────────────────┬──────────────────────────────────────────────────────────────────────┐
# │id │      link      │ joint │     parent     │                                 ETS                                  │
# ├───┼────────────────┼───────┼────────────────┼──────────────────────────────────────────────────────────────────────┤
# │11 │ world          │       │ BASE           │ {world} = {BASE}                                                     │
# │ 1 │ base_link      │       │ world          │ {base_link} = {world}                                                │
# │ 2 │ shoulder_link  │     0 │ base_link      │ {shoulder_link} = {base_link} ⊕ tz(0.08916) ⊕ Rz(q0)                 │
# │ 3 │ upper_arm_link │     1 │ shoulder_link  │ {upper_arm_link} = {shoulder_link} ⊕ ty(0.1358) ⊕ Ry(90°) ⊕ Ry(q1)   │
# │ 4 │ forearm_link   │     2 │ upper_arm_link │ {forearm_link} = {upper_arm_link} ⊕ ty(-0.1197) ⊕ tz(0.425) ⊕ Ry(q2) │
# │ 5 │ wrist_1_link   │     3 │ forearm_link   │ {wrist_1_link} = {forearm_link} ⊕ tz(0.3922) ⊕ Ry(90°) ⊕ Ry(q3)      │
# │ 6 │ wrist_2_link   │     4 │ wrist_1_link   │ {wrist_2_link} = {wrist_1_link} ⊕ ty(0.093) ⊕ Rz(q4)                 │
# │ 7 │ @wrist_3_link  │     5 │ wrist_2_link   │ {wrist_3_link} = {wrist_2_link} ⊕ tz(0.09465) ⊕ Ry(q5)               │
# │10 │ tool0          │       │ wrist_3_link   │ {tool0} = {wrist_3_link} ⊕ ty(0.0823) ⊕ Rx(-90°)                     │
# │ 9 │ base           │       │ base_link      │ {base} = {base_link} ⊕ Rz(-180°)                                     │
# └───┴────────────────┴───────┴────────────────┴──────────────────────────────────────────────────────────────────────┘
#
# ┌─────┬────────┬────────┬────────┬──────┬────────┬─────┐
# │name │ q0     │ q1     │ q2     │ q3   │ q4     │ q5  │
# ├─────┼────────┼────────┼────────┼──────┼────────┼─────┤
# │  qz │  0°    │  0°    │  0°    │  0°  │  0°    │  0° │
# │  qr │  180°  │  0°    │  0°    │  0°  │  90°   │  0° │
# │  qn │ -40.4° │  20.7° │ -85.6° │  65° │ -40.4° │  0° │
# └─────┴────────┴────────┴────────┴──────┴────────┴─────┘
#
# [ELink(world, ets=, m=0, Jm=0, B=0, G=0), ELink(base_link, ets=, parent=world, m=4, I=[0.00443, 0.00443, 0.0072, 0, 0, 0], Jm=0, B=0, G=0), ELink(shoulder_link, ets=tz(0.08916) ⊕ Rz(q), parent=base_link, qlim=[-3.14, 3.14], m=3.7, I=[0.0103, 0.0103, 0.00666, 0, 0, 0], Jm=0, B=0, G=0), ELink(upper_arm_link, ets=ty(0.1358) ⊕ Ry(90°) ⊕ Ry(q), parent=shoulder_link, qlim=[-3.14, 3.14], m=8.39, r=[0, 0, 0.28], I=[0.227, 0.227, 0.0151, 0, 0, 0], Jm=0, B=0, G=0), ELink(forearm_link, ets=ty(-0.1197) ⊕ tz(0.425) ⊕ Ry(q), parent=upper_arm_link, qlim=[-3.14, 3.14], m=2.27, r=[0, 0, 0.196], I=[0.0312, 0.0312, 0.00409, 0, 0, 0], Jm=0, B=0, G=0), ELink(wrist_1_link, ets=tz(0.3922) ⊕ Ry(90°) ⊕ Ry(q), parent=forearm_link, qlim=[-3.14, 3.14], m=1.22, r=[0, 0.093, 0], I=[0.00256, 0.00256, 0.00219, 0, 0, 0], Jm=0, B=0, G=0), ELink(wrist_2_link, ets=ty(0.093) ⊕ Rz(q), parent=wrist_1_link, qlim=[-3.14, 3.14], m=1.22, r=[0, 0, 0.0946], I=[0.00256, 0.00256, 0.00219, 0, 0, 0], Jm=0, B=0, G=0), ELink(wrist_3_link, ets=tz(0.09465) ⊕ Ry(q), parent=wrist_2_link, qlim=[-3.14, 3.14], m=0.188, r=[0, 0.065, 0], I=[8.47e-05, 8.47e-05, 0.000132, 0, 0, 0], Jm=0, B=0, G=0), ELink(tool0, ets=ty(0.0823) ⊕ Rx(-90°), parent=wrist_3_link, m=0, Jm=0, B=0, G=0), ELink(base, ets=Rz(-180°), parent=base_link, m=0, Jm=0, B=0, G=0)]
# [3.14159265 0.         0.         0.         1.57079633 0.        ]

# %%
robot.plot(robot.qr,backend='swift',block=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-ed74992501ab> in <module>
# ----> 1 robot.plot(robot.qr,backend='swift',block=True)
#
# ~\anaconda3\lib\site-packages\roboticstoolbox\robot\Robot.py in plot(self, q, backend, block, dt, limits, vellipse, fellipse, fig, movie, loop, **kwargs)
#    1460         # Keep the plot open
#    1461         if block:  # pragma: no cover
# -> 1462             env.hold()
#    1463
#    1464         return env
#
# ~\anaconda3\lib\site-packages\swift\Swift.py in hold(self)
#     432
#     433         while True:
# --> 434             time.sleep(1)
#     435
#     436     def start_recording(self, file_name, framerate, format="webm"):
#
# KeyboardInterrupt:

# %%
punto1=SE3(  x=300, y=255, z=200)
punto2=SE3(  x=300, y=255, z=85)
punto3=SE3( x=370, y=255, z=85)
punto4=SE3( x=370, y=255, z=600)
punto5=SE3( x=340, y=255, z=600)
punto6=SE3( x=390, y=255, z=600)

# %%
trayegrafc1=rtb.ctraj(punto4, punto3, 150)
trayegrafc2=rtb.ctraj(punto3, punto2, 150)
trayegrafc3=rtb.ctraj(punto2, punto1, 150)
trayegrafc4=rtb.ctraj(punto5, punto6, 150)

# %%
trayegrafc1.plot()
trayegrafc2.plot()
trayegrafc3.plot()
trayegrafc4.plot()

# %%
P1=SE3(x=3.0,y=2.5,z=2.0)
P2=SE3(x=3.0,y=2.5,z=0.8)
P3=SE3(x=3.7,y=2.5,z=0.8)
P4=SE3(x=3.7,y=2.5,z=6.0)
P5=SE3(x=3.4,y=2.5,z=6.0)
P6=SE3(x=3.9,y=2.5,z=6.0)

# %%
pp1 = robot.ikine_min(P1)
pp2 = robot.ikine_min(P2)
pp3 = robot.ikine_min(P3)
pp4 = robot.ikine_min(P4)
pp5 = robot.ikine_min(P5)
pp6 = robot.ikine_min(P6)

# %%
TrayC1=rtb.ctraj(P4, P3, 150)
TrayC2=rtb.ctraj(P3, P2, 150)
TrayC3=rtb.ctraj(P2, P1, 150)
TrayC4=rtb.ctraj(P5, P6, 150)

# %%
InvertrayecC1=robot.ikine_min(TrayC1)
InvertrayecC2=robot.ikine_min(TrayC2)
InvertrayecC3=robot.ikine_min(TrayC3)
InvertrayecC4=robot.ikine_min(TrayC4)

# %%
print(InvertrayecC1)
# Out:
# [IKsolution(q=array([-2.31353637e+00, -3.23410319e+05, -3.23408114e+05, -3.23402797e+05,  8.25361189e-01, -3.23408093e+05]), success=True, reason='Optimization terminated successfully', iterations=37, residual=22.95138332020325), IKsolution(q=array([-2.31354785e+00, -3.23410319e+05, -3.23408114e+05, -3.23402796e+05,  8.25370034e-01, -3.23408093e+05]), success=True, reason='Optimization terminated successfully', iterations=14, residual=22.94839771463778), IKsolution(q=array([-2.31358202e+00, -3.23410319e+05, -3.23408114e+05, -3.23402796e+05,  8.25395969e-01, -3.23408093e+05]), success=True, reason='Optimization terminated successfully', iterations=10, residual=22.93944264957552), IKsolution(q=array([-2.31363913e+00, -3.23410320e+05, -3.23408114e+05, -3.23402796e+05,  8.25439448e-01, -3.23408093e+05]), success=True, reason='Optimization terminated successfully', iterations=15, residual=22.924523379787185), IKsolution(q=array([-2.31371921e+00, -3.23410320e+05, -3.23408114e+05, -3.23402796e+05,  8.25500717e-01, -3.23408093e+05]), success=True, reason='Optimization terminated successfully', iterations=17, residual=22.903648662783205), IKsolution(q=array([-2.31382199e+00, -3.23410320e+05, -3.23408114e+05, -3.23402796e+05,  8.25579076e-01, -3.23408093e+05]), success=True, reason='Optimization terminated successfully', iterations=13, residual=22.876830758152952), IKsolution(q=array([-2.31394775e+00, -3.23410321e+05, -3.23408114e+05, -3.23402796e+05,  8.25675226e-01, -3.23408093e+05]), success=True, reason='Optimization terminated successfully', iterations=16, residual=22.84408542663493), IKsolution(q=array([-2.31409601e+00, -3.23410321e+05, -3.23408114e+05, -3.23402795e+05,  8.25788348e-01, -3.23408093e+05]), success=True, reason='Optimization terminated successfully', iterations=10, residual=22.805431928918445), IKsolution(q=array([-2.31426720e+00, -3.23410322e+05, -3.23408114e+05, -3.23402795e+05,  8.25918974e-01, -3.23408093e+05]), success=True, reason='Optimization terminated successfully', iterations=10, residual=22.760893024172198), IKsolution(q=array([-2.31446114e+00, -3.23410323e+05, -3.23408114e+05, -3.23402794e+05,  8.26067020e-01, -3.23408093e+05]), success=True, reason='Optimization terminated successfully', iterations=12, residual=22.710494968295347), IKsolution(q=array([-2.31467797e+00, -3.23410324e+05, -3.23408114e+05, -3.23402794e+05,  8.26232879e-01, -3.23408092e+05]), success=True, reason='Optimization terminated successfully', iterations=13, residual=22.65426751188706), IKsolution(q=array([-2.31491749e+00, -3.23410325e+05, -3.23408114e+05, -3.23402793e+05,  8.26416002e-01, -3.23408092e+05]), success=True, reason='Optimization terminated successfully', iterations=10, residual=22.592243897928988), IKsolution(q=array([-2.31517967e+00, -3.23410326e+05, -3.23408114e+05, -3.23402792e+05,  8.26616416e-01, -3.23408092e+05]), success=True, reason='Optimization terminated successfully', iterations=15, residual=22.52446085917347), IKsolution(q=array([-2.31546440e+00, -3.23410327e+05, -3.23408114e+05, -3.23402792e+05,  8.26834059e-01, -3.23408092e+05]), success=True, reason='Optimization terminated successfully', iterations=10, residual=22.450958615231485), IKsolution(q=array([-2.31577199e+00, -3.23410328e+05, -3.23408114e+05, -3.23402791e+05,  8.27069622e-01, -3.23408091e+05]), success=True, reason='Optimization terminated successfully', iterations=13, residual=22.3717808693509), IKsolution(q=array([-2.31610209e+00, -3.23410329e+05, -3.23408114e+05, -3.23402790e+05,  8.27322320e-01, -3.23408091e+05]), success=True, reason='Optimization terminated successfully', iterations=17, residual=22.286974804878298), IKsolution(q=array([-2.31645482e+00, -3.23410331e+05, -3.23408114e+05, -3.23402789e+05,  8.27592460e-01, -3.23408091e+05]), success=True, reason='Optimization terminated successfully', iterations=11, residual=22.196591081391528), IKsolution(q=array([-2.31683007e+00, -3.23410332e+05, -3.23408114e+05, -3.23402788e+05,  8.278802 ...

# %%
print(InvertrayecC4)
# Out:
# [IKsolution(q=array([-2.26371831e+00, -3.23410291e+05, -3.23408114e+05, -3.23402823e+05,  7.76318508e-01, -3.23408094e+05]), success=True, reason='Optimization terminated successfully', iterations=36, residual=21.93964287827197), IKsolution(q=array([-2.26372726e+00, -3.23410291e+05, -3.23408114e+05, -3.23402823e+05,  7.76327328e-01, -3.23408094e+05]), success=True, reason='Optimization terminated successfully', iterations=13, residual=21.939806177265183), IKsolution(q=array([-2.26375397e+00, -3.23410291e+05, -3.23408114e+05, -3.23402823e+05,  7.76353730e-01, -3.23408094e+05]), success=True, reason='Optimization terminated successfully', iterations=12, residual=21.94029608961297), IKsolution(q=array([-2.26379863e+00, -3.23410291e+05, -3.23408114e+05, -3.23402823e+05,  7.76397858e-01, -3.23408094e+05]), success=True, reason='Optimization terminated successfully', iterations=11, residual=21.941112661420007), IKsolution(q=array([-2.26386105e+00, -3.23410291e+05, -3.23408114e+05, -3.23402822e+05,  7.76459433e-01, -3.23408094e+05]), success=True, reason='Optimization terminated successfully', iterations=11, residual=21.942255969527974), IKsolution(q=array([-2.26394133e+00, -3.23410291e+05, -3.23408114e+05, -3.23402822e+05,  7.76538945e-01, -3.23408094e+05]), success=True, reason='Optimization terminated successfully', iterations=16, residual=21.943726121516143), IKsolution(q=array([-2.26403928e+00, -3.23410292e+05, -3.23408114e+05, -3.23402822e+05,  7.76635463e-01, -3.23408094e+05]), success=True, reason='Optimization terminated successfully', iterations=17, residual=21.945523255702806), IKsolution(q=array([-2.26415543e+00, -3.23410292e+05, -3.23408114e+05, -3.23402822e+05,  7.76750407e-01, -3.23408094e+05]), success=True, reason='Optimization terminated successfully', iterations=13, residual=21.947647541146015), IKsolution(q=array([-2.26428905e+00, -3.23410292e+05, -3.23408114e+05, -3.23402822e+05,  7.76882488e-01, -3.23408094e+05]), success=True, reason='Optimization terminated successfully', iterations=18, residual=21.95009917764622), IKsolution(q=array([-2.26444056e+00, -3.23410292e+05, -3.23408114e+05, -3.23402822e+05,  7.77032112e-01, -3.23408094e+05]), success=True, reason='Optimization terminated successfully', iterations=13, residual=21.952878395747405), IKsolution(q=array([-2.26460979e+00, -3.23410292e+05, -3.23408114e+05, -3.23402822e+05,  7.77199346e-01, -3.23408094e+05]), success=True, reason='Optimization terminated successfully', iterations=15, residual=21.955985456739704), IKsolution(q=array([-2.26479693e+00, -3.23410292e+05, -3.23408114e+05, -3.23402822e+05,  7.77384235e-01, -3.23408094e+05]), success=True, reason='Optimization terminated successfully', iterations=9, residual=21.959420652662082), IKsolution(q=array([-2.26500150e+00, -3.23410292e+05, -3.23408114e+05, -3.23402822e+05,  7.77586391e-01, -3.23408094e+05]), success=True, reason='Optimization terminated successfully', iterations=12, residual=21.963184306305063), IKsolution(q=array([-2.26522397e+00, -3.23410292e+05, -3.23408114e+05, -3.23402822e+05,  7.77806127e-01, -3.23408094e+05]), success=True, reason='Optimization terminated successfully', iterations=12, residual=21.96727677121412), IKsolution(q=array([-2.26546389e+00, -3.23410292e+05, -3.23408114e+05, -3.23402822e+05,  7.78043261e-01, -3.23408094e+05]), success=True, reason='Optimization terminated successfully', iterations=12, residual=21.971698431693067), IKsolution(q=array([-2.26572164e+00, -3.23410292e+05, -3.23408114e+05, -3.23402822e+05,  7.78297822e-01, -3.23408094e+05]), success=True, reason='Optimization terminated successfully', iterations=9, residual=21.976449702807855), IKsolution(q=array([-2.26599697e+00, -3.23410293e+05, -3.23408114e+05, -3.23402821e+05,  7.78569868e-01, -3.23408094e+05]), success=True, reason='Optimization terminated successfully', iterations=16, residual=21.98153103039084), IKsolution(q=array([-2.26628981e+00, -3.23410293e+05, -3.23408114e+05, -3.23402821e+05,  7.78859 ...

# %%
Trayec1 = rtb.jtraj(InvertrayecC1[0].q, InvertrayecC1[-1].q, 150)
Trayec2 = rtb.jtraj(InvertrayecC2[0].q, InvertrayecC2[-1].q, 150)
Trayec3 = rtb.jtraj(InvertrayecC3[0].q, InvertrayecC3[-1].q, 150)
Trayec4 = rtb.jtraj(InvertrayecC4[0].q, InvertrayecC4[-1].q, 150)

# %%
robot.plot(Trayec1.q,block=False)
robot.plot(Trayec2.q,block=False)
robot.plot(Trayec3.q,block=False)
robot.plot(Trayec4.q,block=False)
# Out:
# Swift backend, t = 7.499999999999981, scene:
#   UR5

# %%
traj = rtb.jtraj(pp1.q, pp2.q, np.arange(0,10,0.1), qd0=np.array([pi/4, 0.5, pi/4, 0.5, pi/4, 0.5]),qd1=np.array([pi/4, 0.5, pi/4, 0.5, pi/4, 0.5]))
traj.plot()
#https://petercorke.github.io/robotics-toolbox-python/arm_trajectory.html
#posicion, velocidad y aceleracion

# %%
vg1 = robot.jacob0(pp1.q)
vg2 = robot.jacob0(pp2.q)
vg3 = robot.jacob0(pp3.q)
vg4 = robot.jacob0(pp4.q)
vg5 = robot.jacob0(pp5.q)
vg6 = robot.jacob0(pp6.q)

# %%
vm1=np.linalg.pinv(robot.jacob0(pp1.q))
vm2=np.linalg.pinv(robot.jacob0(pp2.q))
vm3=np.linalg.pinv(robot.jacob0(pp3.q))
vm4=np.linalg.pinv(robot.jacob0(pp4.q))
vm5=np.linalg.pinv(robot.jacob0(pp5.q))
vm6=np.linalg.pinv(robot.jacob0(pp6.q))
#https://numpy.org/doc/stable/reference/generated/numpy.linalg.pinv.html
